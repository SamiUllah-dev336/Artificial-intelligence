# %%
d={
    'a':[('b',2),('c',1)],
    'b':[('a',2),('d',3),('f',1)],
    'c':[('a',1),('d',3),('g',4)],
    'd':[('b',3),('c',3),('e',5),('g',4)],
    'e':[('d',5)],
    'f':[('b',1)],
    'g':[('c',4),('d',1)]
}

#reverse close function
def reverseClose(visited, goalNode):
    path = [];
    path.append(goalNode);
    length = len(visited);
    goalNode = visited[length-1];
    prevLen=length-2;
    previousNode=visited[prevLen];
    
    while length > 1:
        
        if previousNode[1] == goalNode[0]:
            path.append(previousNode[1]);
            goalNode = previousNode;
            prevLen-=1;
            previousNode=visited[prevLen];
            length -= 1;
        else:
            prevLen-=1;
            previousNode=visited[prevLen];
            length -= 1;

    print('Path to get goal node',' <- '.join(path));

def UCS(d,start,end):
    #stack is used to store list of pairs
    queue=[];
    tuple1=('',start,0);
    queue.append(tuple1);
    visited=[];

    while queue:
        parent,child,costP=queue.pop(0);
        popPair=(parent,child,costP);
        print(popPair);

        if child==end:
            visited.append(popPair);
            print(f"{child} is a goal!");
            print("visited",visited);
            reverseClose(visited,child);
            return;
        else:
            visited.append(popPair);
            for subChild in d[child]:
                not_found = not any(subChild[0] in node for node in visited);
                if not_found:
                    total_cost=costP+subChild[1];        
                    pair1=(child,subChild[0],total_cost);
                    queue.append(pair1);
            queue=sorted(queue, key=lambda x: x[2]);
            print("sorted queue!",queue);              

UCS(d,'a','e');
# Out:
# ('', 'a', 0)
# sorted queue! [('a', 'c', 1), ('a', 'b', 2)]
# ('a', 'c', 1)
# sorted queue! [('a', 'b', 2), ('c', 'd', 4), ('c', 'g', 5)]
# ('a', 'b', 2)
# sorted queue! [('b', 'f', 3), ('c', 'd', 4), ('c', 'g', 5), ('b', 'd', 5)]
# ('b', 'f', 3)
# sorted queue! [('c', 'd', 4), ('c', 'g', 5), ('b', 'd', 5)]
# ('c', 'd', 4)
# sorted queue! [('c', 'g', 5), ('b', 'd', 5), ('d', 'g', 8), ('d', 'e', 9)]
# ('c', 'g', 5)
# sorted queue! [('b', 'd', 5), ('d', 'g', 8), ('d', 'e', 9)]
# ('b', 'd', 5)
# sorted queue! [('d', 'g', 8), ('d', 'e', 9), ('d', 'e', 10)]
# ('d', 'g', 8)
# sorted queue! [('d', 'e', 9), ('d', 'e', 10)]
# ('d', 'e', 9)
# e is a goal!
# visited [('', 'a', 0), ('a', 'c', 1), ('a', 'b', 2), ('b', 'f', 3), ('c', 'd', 4), ('c', 'g', 5), ('b', 'd', 5), ('d', 'g', 8), ('d', 'e', 9)]
# Path to get goal node e <- d <- b <- a
